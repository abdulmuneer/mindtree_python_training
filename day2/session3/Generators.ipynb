# %% [markdown]
# Easier way to create iterators using a keyword yield from a function.

# %%
def my_generator():
    print("Inside my generator")
    yield 'a'
    yield 'b'
    yield 'c'

my_generator()
# Out:
# <generator object my_generator at 0x7f77741d4f50>

# %%
m = my_generator()

# %%
m.next()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-51-e94cbac0601a> in <module>()
# ----> 1 m.next()
#
# StopIteration:

# %%
for char in my_generator():
    print char
# Out:
# Inside my generator
# a
# b
# c

# %%
list(my_generator())
# Out:
# Inside my generator
# ['a', 'b', 'c']

# %%
#similar to the while loop example in iterators
def counter_generator(low, high):
    while low <= high:
        yield low
        low += 1

# %%
for i in counter_generator(5,10):
    print i ,
# Out:
# 5 6 7 8 9 10

# %%
#infinite sequences
def infinite_generator(start=0):
    
    while True:
        yield start
        start += 1

# %%
a = infinite_generator()

# %%
a
# Out:
# <generator object infinite_generator at 0x7f77741762d0>

# %%
dir(a)
# Out:
# ['__class__',
#  '__delattr__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__name__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'close',
#  'gi_code',
#  'gi_frame',
#  'gi_running',
#  'next',
#  'send',
#  'throw']

# %%
a.next()
# Out:
# 22

# %%
def fib():
    t1, t2 = 0, 1
    yield t2
    while True:
        t1, t2 = t2, t2+t1
        yield t2

# %%
f = fib()

# %%
f.next()
# Out:
# 21

# %%
#Reusable generator
class Counter(object):
    def __init__(self, low, high):
        self.low = low
        self.high = high
    def __iter__(self):
        counter = self.low
        while self.high >= counter:
            yield counter
            counter += 1

# %%
gobj = Counter(5, 10)

# %%
for i in gobj:
    print i,
# Out:
# 5 6 7 8 9 10

# %%
for i in gobj:
    print i,
# Out:
# 5 6 7 8 9 10

# %% [markdown]
# ### Generator expressions

# %%
L = [x*x for x in range(1,10)]
# sum(L)
print L
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
G = (x*x for x in range(1,10))
print G
# sum(G)
# Out:
# <generator object <genexpr> at 0x7fa19c14c5a0>

# %%
print sum(L)
print sum(G)
# Out:
# 285
# 285

# %%
x = 10
y = 20

a = 'Hello'
b = 'World'

print x+y
print a+b
# Out:
# 30
# HelloWorld

# %%
help(x.__add__)
# Out:
# Help on method-wrapper object:
#
# __add__ = class method-wrapper(object)
#  |  Methods defined here:
#  |
#  |  __call__(...)
#  |      x.__call__(...) <==> x(...)
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __hash__(...)
#  |      x.__hash__() <==> hash(x)
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __objclass__
#  |
#  |  __self__

# %%
help(a.__add__)
# Out:
# Help on method-wrapper object:
#
# __add__ = class method-wrapper(object)
#  |  Methods defined here:
#  |
#  |  __call__(...)
#  |      x.__call__(...) <==> x(...)
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __hash__(...)
#  |      x.__hash__() <==> hash(x)
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __objclass__
#  |
#  |  __self__

# %%
class Multiplier(object):
    def __init__(self, n):
        self.n = n
        
    def __call__(self, i):
        return self.n * i
    
    def __greet(self):
        return "Hidden"
    def _greet(self):
        return "Hello"
    
m3 = Multiplier(3)


#print m3.greet()
#print m3(10)
m4 = Multiplier(4)
print m4._greet()
#print m4.__greet()
m4.__dict__
print m4._Multiplier__greet()
dir(m4)
# Out:
# Hello
# Hidden
# ['_Multiplier__greet',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_greet',
#  'n']

# %%
callable(m3)
# Out:
# True

# %%
x = list
y = list((1,2,3))
# print dir(x)
