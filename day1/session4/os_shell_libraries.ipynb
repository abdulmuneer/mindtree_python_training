# %% [markdown]
# - Shell utilities
# - os module

# %%
import os

# %%
os.uname
# Out:
# <function posix.uname>

# %%
print dir(os)
# Out:
# ['EX_CANTCREAT', 'EX_CONFIG', 'EX_DATAERR', 'EX_IOERR', 'EX_NOHOST', 'EX_NOINPUT', 'EX_NOPERM', 'EX_NOUSER', 'EX_OK', 'EX_OSERR', 'EX_OSFILE', 'EX_PROTOCOL', 'EX_SOFTWARE', 'EX_TEMPFAIL', 'EX_UNAVAILABLE', 'EX_USAGE', 'F_OK', 'NGROUPS_MAX', 'O_APPEND', 'O_ASYNC', 'O_CREAT', 'O_DIRECT', 'O_DIRECTORY', 'O_DSYNC', 'O_EXCL', 'O_LARGEFILE', 'O_NDELAY', 'O_NOATIME', 'O_NOCTTY', 'O_NOFOLLOW', 'O_NONBLOCK', 'O_RDONLY', 'O_RDWR', 'O_RSYNC', 'O_SYNC', 'O_TRUNC', 'O_WRONLY', 'P_NOWAIT', 'P_NOWAITO', 'P_WAIT', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'UserDict', 'WCONTINUED', 'WCOREDUMP', 'WEXITSTATUS', 'WIFCONTINUED', 'WIFEXITED', 'WIFSIGNALED', 'WIFSTOPPED', 'WNOHANG', 'WSTOPSIG', 'WTERMSIG', 'WUNTRACED', 'W_OK', 'X_OK', '_Environ', '__all__', '__builtins__', '__doc__', '__file__', '__name__', '__package__', '_copy_reg', '_execvpe', '_exists', '_exit', '_get_exports_list', '_make_stat_result', '_make_statvfs_result', '_pickle_stat_result', '_pickle_statvfs_result', '_spawnvef', '
# ...

# %%
os.getcwd()
# Out:
# '/home/m1032077/python training/mindtree/day1/session4'

# %%
x = os.getcwd()
print x
from pprint import pprint
for a, b, c in os.walk(os.path.split(x)[0]):
    pprint(a, b, c)
# Out:
# /home/m1032077/python training/mindtree/day1/session4
# /home/m1032077/python training/mindtree/day1 ['session2', 'session1', 'session4', 'session3'] ['.DS_Store', '._.DS_Store']
# /home/m1032077/python training/mindtree/day1/session2 ['.ipynb_checkpoints'] ['properties_descriptors_slots.ipynb', 'Anonymous_Functions.ipynb', 'comprehensions.ipynb', 'string_processing.ipynb', 'property_simple.ipynb']
# /home/m1032077/python training/mindtree/day1/session2/.ipynb_checkpoints [] ['Anonymous_Functions-checkpoint.ipynb', 'property_simple-checkpoint.ipynb', 'properties_descriptors_slots-checkpoint.ipynb', 'string_processing-checkpoint.ipynb', 'comprehensions-checkpoint.ipynb']
# /home/m1032077/python training/mindtree/day1/session1 ['.ipynb_checkpoints'] ['test.py', 'datatypes_controlflow.ipynb', 'modules.ipynb', 'Untitled.ipynb', '.DS_Store', '._.DS_Store', 'identity_introspection.ipynb', 'functions.ipynb', 'oop_basics.ipynb']
# ...

# %%
import glob
glob.glob('*a*')
# Out:
# ['os_shell_libraries.ipynb', 'map_filter_reduce.ipynb']

# %%
y = os.path.split(x)
y
# Out:
# ('/home/m1032077/python training/mindtree/day1', 'session4')

# %%
os.path.join('abc', 'def')
# Out:
# 'abc/def'

# %%
os.listdir('/home')
# Out:
# ['m1032077']

# %%
os.environ
# Out:
# {'MANDATORY_PATH': '/usr/share/gconf/ubuntu.mandatory.path', 'XDG_GREETER_DATA_DIR': '/var/lib/lightdm-data/m1032077', 'GNOME_DESKTOP_SESSION_ID': 'this-is-deprecated', 'UPSTART_EVENTS': 'xsession started', 'LESSOPEN': '| /usr/bin/lesspipe %s', 'XDG_SESSION_TYPE': 'x11', 'QT_IM_MODULE': 'ibus', 'LOGNAME': 'm1032077', 'USER': 'm1032077', 'GNOME_KEYRING_CONTROL': '', 'XDG_VTNR': '7', 'PATH': '/home/m1032077/anaconda2/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games', 'CLICOLOR': '1', 'DISPLAY': ':0', 'LANG': 'en_IN', 'TERM': 'xterm-color', 'SHELL': '/bin/bash', 'XDG_SESSION_PATH': '/org/freedesktop/DisplayManager/Session0', 'XAUTHORITY': '/home/m1032077/.Xauthority', 'LANGUAGE': 'en_IN:en', 'INSTANCE': '', 'SHLVL': '1', 'QT_QPA_PLATFORMTHEME': 'appmenu-qt5', 'COMPIZ_CONFIG_PROFILE': 'ubuntu', 'UPSTART_INSTANCE': '', 'JOB': 'unity-settings-daemon', 'WINDOWID': '77594634', 'SESSIONTYPE': 'gnome-session', 'CLUTTER_IM_MODULE': 'xim', 'XMODIFIERS'
# ...

# %%
[x for x in dir(os) if 'env' in x]
# Out:
# ['environ', 'getenv', 'putenv', 'unsetenv']

# %%
import sys
print sys.modules
# Out:
# {'email.MIMEAudio': <email.LazyImporter object at 0x7f7359fbcad0>, 'IPython.core.error': <module 'IPython.core.error' from '/home/m1032077/anaconda2/lib/python2.7/site-packages/IPython/core/error.pyc'>, 'ipython_genutils.py3compat': <module 'ipython_genutils.py3compat' from '/home/m1032077/anaconda2/lib/python2.7/site-packages/ipython_genutils/py3compat.pyc'>, 'traitlets.config.sys': None, 'ipykernel.parentpoller': <module 'ipykernel.parentpoller' from '/home/m1032077/anaconda2/lib/python2.7/site-packages/ipykernel/parentpoller.pyc'>, 'traitlets.config.decorator': None, 'ctypes.os': None, 'pexpect.select': None, 'runpy': <module 'runpy' from '/home/m1032077/anaconda2/lib/python2.7/runpy.pyc'>, 'gc': <module 'gc' (built-in)>, 'pty': <module 'pty' from '/home/m1032077/anaconda2/lib/python2.7/pty.pyc'>, 'tornado.escape': <module 'tornado.escape' from '/home/m1032077/anaconda2/lib/python2.7/site-packages/tornado/escape.pyc'>, 'IPython.utils.pprint': None, 'email.warnings': None, 'jupyter
# ...

# %%
import shutil
dir(shutil)
# Out:
# ['Error',
#  'ExecError',
#  'SpecialFileError',
#  'WindowsError',
#  '_ARCHIVE_FORMATS',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '_basename',
#  '_call_external_zip',
#  '_destinsrc',
#  '_get_gid',
#  '_get_uid',
#  '_make_tarball',
#  '_make_zipfile',
#  '_samefile',
#  'abspath',
#  'collections',
#  'copy',
#  'copy2',
#  'copyfile',
#  'copyfileobj',
#  'copymode',
#  'copystat',
#  'copytree',
#  'errno',
#  'fnmatch',
#  'get_archive_formats',
#  'getgrnam',
#  'getpwnam',
#  'ignore_patterns',
#  'make_archive',
#  'move',
#  'os',
#  'register_archive_format',
#  'rmtree',
#  'stat',
#  'sys',
#  'unregister_archive_format']

# %%
x = raw_input("enter your name")

# %%
x
